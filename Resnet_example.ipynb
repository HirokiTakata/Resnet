# %%
# !wget https://s3.amazonaws.com/fast-ai-imageclas/imagenette-320.tgz
# !tar xzf imagenette-320.tgz
# Out:
# --2020-12-15 13:04:48--  https://s3.amazonaws.com/fast-ai-imageclas/imagenette-320.tgz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.85.85
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.85.85|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 341289752 (325M) [application/x-tar]
# Saving to: ‘imagenette-320.tgz’
#
# imagenette-320.tgz  100%[===================>] 325.48M  48.3MB/s    in 7.2s
#
# 2020-12-15 13:04:55 (45.4 MB/s) - ‘imagenette-320.tgz’ saved [341289752/341289752]

# %%
# !wget https://s3.amazonaws.com/fast-ai-imageclas/imagenette-320.tgz
# !tar xzf imagenette-320.tgz
# Out:
# --2020-12-15 23:14:17--  https://s3.amazonaws.com/fast-ai-imageclas/imagenette-320.tgz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.43.110
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.43.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 341289752 (325M) [application/x-tar]
# Saving to: ‘imagenette-320.tgz’
#
# imagenette-320.tgz  100%[===================>] 325.48M  45.9MB/s    in 7.6s
#
# 2020-12-15 23:14:25 (43.0 MB/s) - ‘imagenette-320.tgz’ saved [341289752/341289752]

# %%
# !git clone http://github.com/pytorch/examples
# Out:
# Cloning into 'examples'...
# ...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 2646 (delta 13), reused 12 (delta 7), pack-reused 2617
# Receiving objects: 100% (2646/2646), 39.11 MiB | 21.69 MiB/s, done.
# Resolving deltas: 100% (1323/1323), done.

# %%
# !python3 examples/imagenet/main.py -a resnet18 -j 2 --epochs 10 imagenette-320/
# Out:
# => creating model 'resnet18'
# Epoch: [0][ 0/51]	Time  6.051 ( 6.051)	Data  2.513 ( 2.513)	Loss 6.8400e+00 (6.8400e+00)	Acc@1   0.00 (  0.00)	Acc@5   0.00 (  0.00)
# Epoch: [0][10/51]	Time  0.691 ( 1.266)	Data  0.063 ( 0.482)	Loss 2.8978e+00 (4.5337e+00)	Acc@1  13.67 ( 13.25)	Acc@5  53.91 ( 49.96)
# Epoch: [0][20/51]	Time  0.700 ( 1.150)	Data  0.345 ( 0.599)	Loss 3.0870e+00 (3.9323e+00)	Acc@1  14.84 ( 13.58)	Acc@5  62.50 ( 53.94)
# Epoch: [0][30/51]	Time  0.715 ( 1.117)	Data  0.219 ( 0.634)	Loss 2.3506e+00 (3.4423e+00)	Acc@1  22.27 ( 15.35)	Acc@5  67.58 ( 57.06)
# Epoch: [0][40/51]	Time  0.715 ( 1.108)	Data  0.083 ( 0.631)	Loss 2.1452e+00 (3.1531e+00)	Acc@1  21.48 ( 17.37)	Acc@5  75.00 ( 61.16)
# Epoch: [0][50/51]	Time  1.837 ( 1.109)	Data  0.000 ( 0.623)	Loss 1.8251e+00 (2.9652e+00)	Acc@1  35.11 ( 18.99)	Acc@5  84.04 ( 63.94)
# Test: [0/2]	Time  2.447 ( 2.447)	Loss 2.2205e+00 (2.2205e+00)	Acc@1  14.45 ( 14.45)	Acc@5  77.34 ( 77.34)
#  * Acc@1 28.400 Acc@5 75.800
# ...

# %%
# !python3 examples/imagenet/main.py -a resnet34 -j 2 --epochs 10 imagenette-320/
# Out:
# => creating model 'resnet34'
# Epoch: [0][ 0/51]	Time  6.468 ( 6.468)	Data  2.222 ( 2.222)	Loss 7.0837e+00 (7.0837e+00)	Acc@1   0.00 (  0.00)	Acc@5   4.30 (  4.30)
# Epoch: [0][10/51]	Time  1.199 ( 1.590)	Data  0.000 ( 0.205)	Loss 1.5450e+01 (1.0074e+01)	Acc@1   7.42 ( 10.16)	Acc@5  46.48 ( 45.63)
# Epoch: [0][20/51]	Time  1.162 ( 1.394)	Data  0.000 ( 0.183)	Loss 3.7943e+00 (8.8463e+00)	Acc@1  11.33 ( 10.36)	Acc@5  52.73 ( 47.28)
# Epoch: [0][30/51]	Time  1.215 ( 1.336)	Data  0.000 ( 0.218)	Loss 3.9166e+00 (7.4314e+00)	Acc@1   8.20 ( 10.14)	Acc@5  51.17 ( 48.27)
# Epoch: [0][40/51]	Time  1.271 ( 1.317)	Data  0.000 ( 0.230)	Loss 2.4616e+00 (6.3163e+00)	Acc@1  10.94 ( 10.21)	Acc@5  54.69 ( 48.76)
# Epoch: [0][50/51]	Time  2.503 ( 1.338)	Data  0.000 ( 0.226)	Loss 2.4788e+00 (5.5897e+00)	Acc@1   9.57 ( 10.55)	Acc@5  45.74 ( 49.57)
# Test: [0/2]	Time  2.684 ( 2.684)	Loss 2.5219e+00 (2.5219e+00)	Acc@1   5.08 (  5.08)	Acc@5  54.69 ( 54.69)
#  * Acc@1 11.200 Acc@5 51.200
# ...

# %%
# !python3 examples/imagenet/main.py -a resnet34 -j 2 --epochs 30 imagenette-320/
# Out:
# => creating model 'resnet34'
# Epoch: [0][ 0/51]	Time  6.296 ( 6.296)	Data  2.399 ( 2.399)	Loss 7.3599e+00 (7.3599e+00)	Acc@1   0.00 (  0.00)	Acc@5   0.00 (  0.00)
# Epoch: [0][10/51]	Time  1.106 ( 1.527)	Data  0.081 ( 0.228)	Loss 9.8343e+00 (8.6253e+00)	Acc@1  10.55 ( 10.01)	Acc@5  43.36 ( 46.06)
# Epoch: [0][20/51]	Time  1.142 ( 1.346)	Data  0.668 ( 0.319)	Loss 4.2302e+00 (7.1005e+00)	Acc@1   8.98 ( 10.32)	Acc@5  51.95 ( 48.27)
# Epoch: [0][30/51]	Time  1.156 ( 1.281)	Data  0.710 ( 0.357)	Loss 2.6747e+00 (5.9545e+00)	Acc@1  15.62 ( 11.03)	Acc@5  58.59 ( 49.84)
# Epoch: [0][40/51]	Time  1.170 ( 1.254)	Data  0.628 ( 0.376)	Loss 2.2752e+00 (5.1145e+00)	Acc@1  14.45 ( 11.79)	Acc@5  58.20 ( 50.87)
# Epoch: [0][50/51]	Time  2.273 ( 1.260)	Data  0.000 ( 0.370)	Loss 2.2205e+00 (4.7292e+00)	Acc@1  15.96 ( 12.11)	Acc@5  58.51 ( 51.68)
# Test: [0/2]	Time  2.651 ( 2.651)	Loss 4.4265e+00 (4.4265e+00)	Acc@1   9.38 (  9.38)	Acc@5  43.75 ( 43.75)
#  * Acc@1 11.800 Acc@5 58.200
# ...

# %%
# !python3 examples/imagenet/main.py -a resnet18 -j 2 --epochs 30 imagenette-320/
# Out:
# => creating model 'resnet18'
# Epoch: [0][ 0/51]	Time  5.683 ( 5.683)	Data  2.112 ( 2.112)	Loss 7.0009e+00 (7.0009e+00)	Acc@1   0.00 (  0.00)	Acc@5   0.00 (  0.00)
# Epoch: [0][10/51]	Time  0.664 ( 1.212)	Data  0.099 ( 0.443)	Loss 5.2693e+00 (6.6018e+00)	Acc@1  17.19 ( 12.00)	Acc@5  53.12 ( 48.33)
# Epoch: [0][20/51]	Time  0.691 ( 1.140)	Data  0.173 ( 0.559)	Loss 4.0566e+00 (6.9503e+00)	Acc@1  11.33 ( 11.96)	Acc@5  52.73 ( 49.78)
# Epoch: [0][30/51]	Time  0.682 ( 1.131)	Data  0.000 ( 0.592)	Loss 4.6644e+00 (5.9183e+00)	Acc@1  10.55 ( 12.32)	Acc@5  48.44 ( 50.97)
# Epoch: [0][40/51]	Time  0.675 ( 1.115)	Data  0.098 ( 0.604)	Loss 3.1526e+00 (5.3290e+00)	Acc@1  11.72 ( 11.86)	Acc@5  57.81 ( 51.44)
# Epoch: [0][50/51]	Time  1.725 ( 1.123)	Data  0.000 ( 0.607)	Loss 2.4893e+00 (4.8304e+00)	Acc@1   9.57 ( 11.90)	Acc@5  54.26 ( 51.82)
# Test: [0/2]	Time  2.453 ( 2.453)	Loss 2.2069e+00 (2.2069e+00)	Acc@1  20.70 ( 20.70)	Acc@5  59.38 ( 59.38)
#  * Acc@1 11.200 Acc@5 51.800
# ...

# %%
# !python3 examples/imagenet/main.py -a resnet34 -j 2 --epochs 50 imagenette-320/
# Out:
# => creating model 'resnet34'
# Epoch: [0][ 0/51]	Time  6.153 ( 6.153)	Data  2.094 ( 2.094)	Loss 6.8184e+00 (6.8184e+00)	Acc@1   0.00 (  0.00)	Acc@5   0.00 (  0.00)
# Epoch: [0][10/51]	Time  1.134 ( 1.531)	Data  0.000 ( 0.194)	Loss 1.5079e+01 (1.2328e+01)	Acc@1  10.55 ( 10.12)	Acc@5  52.73 ( 47.16)
# Epoch: [0][20/51]	Time  1.141 ( 1.349)	Data  0.303 ( 0.215)	Loss 4.9450e+00 (9.4919e+00)	Acc@1   9.38 (  9.77)	Acc@5  51.56 ( 49.09)
# Epoch: [0][30/51]	Time  1.171 ( 1.299)	Data  0.681 ( 0.291)	Loss 3.6861e+00 (7.6963e+00)	Acc@1  10.16 ( 10.06)	Acc@5  51.56 ( 49.95)
# Epoch: [0][40/51]	Time  1.226 ( 1.274)	Data  0.632 ( 0.322)	Loss 2.6071e+00 (6.5430e+00)	Acc@1  12.89 ( 10.27)	Acc@5  51.95 ( 50.53)
# Epoch: [0][50/51]	Time  2.354 ( 1.284)	Data  0.000 ( 0.323)	Loss 2.3513e+00 (5.7880e+00)	Acc@1  11.70 ( 10.74)	Acc@5  55.32 ( 51.35)
# Test: [0/2]	Time  2.600 ( 2.600)	Loss 3.4348e+00 (3.4348e+00)	Acc@1   7.81 (  7.81)	Acc@5  80.47 ( 80.47)
#  * Acc@1 12.000 Acc@5 59.000
# ...

# %%
# !python3 examples/imagenet/main.py -a resnet18 -j 2 --epochs 50 imagenette-320/
# Out:
# => creating model 'resnet18'
# Epoch: [0][ 0/51]	Time  6.160 ( 6.160)	Data  2.687 ( 2.687)	Loss 6.9501e+00 (6.9501e+00)	Acc@1   0.00 (  0.00)	Acc@5   0.39 (  0.39)
# Epoch: [0][10/51]	Time  0.658 ( 1.282)	Data  0.005 ( 0.524)	Loss 8.0572e+00 (5.9313e+00)	Acc@1   8.20 ( 10.30)	Acc@5  46.88 ( 48.22)
# Epoch: [0][20/51]	Time  0.665 ( 1.209)	Data  0.000 ( 0.599)	Loss 3.0837e+00 (5.2356e+00)	Acc@1  14.84 ( 10.81)	Acc@5  55.08 ( 48.88)
# Epoch: [0][30/51]	Time  0.683 ( 1.177)	Data  0.000 ( 0.624)	Loss 2.3996e+00 (4.3985e+00)	Acc@1  16.41 ( 12.24)	Acc@5  59.77 ( 51.60)
# Epoch: [0][40/51]	Time  0.686 ( 1.159)	Data  0.000 ( 0.635)	Loss 2.2328e+00 (3.8759e+00)	Acc@1  12.89 ( 13.53)	Acc@5  73.05 ( 54.88)
# Epoch: [0][50/51]	Time  1.716 ( 1.155)	Data  0.000 ( 0.628)	Loss 2.1770e+00 (3.5593e+00)	Acc@1  32.98 ( 15.53)	Acc@5  69.15 ( 57.58)
# Test: [0/2]	Time  2.546 ( 2.546)	Loss 2.2408e+00 (2.2408e+00)	Acc@1  11.72 ( 11.72)	Acc@5  68.36 ( 68.36)
#  * Acc@1 29.200 Acc@5 75.400
# ...
